# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, VotingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor

from pycaret.regression import setup, compare_models
import optuna

# %% [markdown]
# # Data Loading

# %%
train = pd.read_csv('train.csv', index_col='id')
test = pd.read_csv('test.csv', index_col='id')
ss = pd.read_csv('sample_submission.csv')

# %% [markdown]
# # EDA

# %%
train.shape
# Out:
# (15289, 17)

# %%
train.isnull().sum()
# Out:
# clonesize               0
# honeybee                0
# bumbles                 0
# andrena                 0
# osmia                   0
# MaxOfUpperTRange        0
# MinOfUpperTRange        0
# AverageOfUpperTRange    0
# MaxOfLowerTRange        0
# MinOfLowerTRange        0
# AverageOfLowerTRange    0
# RainingDays             0
# AverageRainingDays      0
# fruitset                0
# fruitmass               0
# seeds                   0
# yield                   0
# dtype: int64

# %%
train.describe()
# Out:
#           clonesize      honeybee       bumbles       andrena         osmia  \
# count  15289.000000  15289.000000  15289.000000  15289.000000  15289.000000
# mean      19.704690      0.389314      0.286768      0.492675      0.592355
# std        6.595211      0.361643      0.059917      0.148115      0.139489
# min       10.000000      0.000000      0.000000      0.000000      0.000000
# 25%       12.500000      0.250000      0.250000      0.380000      0.500000
# 50%       25.000000      0.500000      0.250000      0.500000      0.630000
# 75%       25.000000      0.500000      0.380000      0.630000      0.750000
# max       40.000000     18.430000      0.585000      0.750000      0.750000
#
#        MaxOfUpperTRange  MinOfUpperTRange  AverageOfUpperTRange  \
# count      15289.000000      15289.000000          15289.000000
# mean          82.169887         49.673281             68.656256
# std            9.146703          5.546405              7.641807
# min           69.700000         39.000000             58.200000
# 25%           77.400000         46.800000             64.700000
# 50%           86.000000         52.000000             71.900000
# 75%           86.000000         52.000000             71.900000
# max           94.600000         57.200000             79.000000
#
#        MaxOfLowerTRange  MinOfLowerTRange  AverageOfLowerTRange   RainingDays  \
# count      15289.000000      15289.000000          15289.000000  15289.000000
# mean          59.229538         28.660553             48.568500     18.660865
# std            6.610640          3.195367              5.390545     11.657582
# min           50.200000         24.300000             41.200000      1.000000
# 25%           55.800000         27.000000             45.800000     16.000000
# 50%           62.000000         30.000000             50.800000     16.000000
# 75%           62.000000         30.000000             50.800000     24.000000
# max           68.200000         33.000000             55.900000     34.000000
#
#        AverageRainingDays      fruitset     fruitmass         seeds  \
# count        15289.000000  15289.000000  15289.000000  15289.000000
# mean             0.324176      0.502741      0.446553     36.164950
# std              0.163905      0.074390      0.037035      4.031087
# min              0.060000      0.192732      0.311921     22.079199
# 25%              0.260000      0.458246      0.419216     33.232449
# 50%              0.260000      0.506600      0.446570     36.040675
# 75%              0.390000      0.560445      0.474134     39.158238
# max              0.560000      0.652144      0.535660     46.585105
#
#               yield
# count  15289.000000
# mean    6025.193999
# std     1337.056850
# min     1945.530610
# 25%     5128.163510
# 50%     6117.475900
# 75%     7019.694380
# max     8969.401840

# %%
sns.set(rc={'figure.figsize':(12, 8)})
sns.heatmap(train.corr().round(2), annot=True)
plt.show()

# %% [markdown]
# # Combine Train and Test Data

# %%
train1 = train.drop('yield', axis=1).copy()

# %%
train1 = pd.concat([train1, test])

# %% [markdown]
# # Feature Engineering

# %%
train2 = train1.copy()

# %%
# Based on the correlation matrix, these parameters are highly correlated and have the same correlation with the target so it is safe to remove them
train2 = train2.drop(['MinOfUpperTRange', 'AverageOfUpperTRange', 'MaxOfLowerTRange', 'MinOfLowerTRange', 'AverageOfLowerTRange', 'RainingDays'], axis=1)
#, 'fruitmass', 'seeds'

# %% [markdown]
# # Feature Scaling

# %%
train3 = train2.copy()

# %%
sc = StandardScaler()
train3 = pd.DataFrame(sc.fit_transform(train3), columns=train3.columns)

# %% [markdown]
# # Target Transformation

# %%
y = train['yield']

# %%
sns.histplot(y)
plt.show()

# %% [markdown]
# # Split Train and Test data, transform

# %%
X = train3.loc[:train.index.max(), :].copy()
test_transformed = train3.iloc[train.index.max()+1:, :]

# %% [markdown]
# # Compare Models

# %%
_ = setup(data=pd.concat([X, y], axis=1), target='yield')
# Out:
# <style type="text/css">
# #T_b20ef_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b20ef_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b20ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b20ef_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b20ef_row0_col1" class="data row0 col1" >1067</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b20ef_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b20ef_row1_col1" class="data row1 col1" >yield</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b20ef_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b20ef_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b20ef_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b20ef_row3_col1" class="data row3 col1" >(15289, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b20ef_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b20ef_row4_col1" class="data row4 col1" >(15289, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b20ef_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b20ef_row5_col1" class="data row5 col1" >(10702, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b20ef_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b20ef_row6_col1" class="data row6 col1" >(4587, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b20ef_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b20ef_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b20ef_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b20ef_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b20ef_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b20ef_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b20ef_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b20ef_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b20ef_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b20ef_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b20ef_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b20ef_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b20ef_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b20ef_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b20ef_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b20ef_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b20ef_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b20ef_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b20ef_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b20ef_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b20ef_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b20ef_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b20ef_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b20ef_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b20ef_row18_col1" class="data row18 col1" >16de</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_ef245_ th {
#   text-align: left;
# }
# #T_ef245_row0_col0, #T_ef245_row0_col2, #T_ef245_row1_col0, #T_ef245_row1_col1, #T_ef245_row1_col3, #T_ef245_row1_col5, #T_ef245_row1_col6, #T_ef245_row2_col0, #T_ef245_row2_col1, #T_ef245_row2_col2, #T_ef245_row2_col3, #T_ef245_row2_col4, #T_ef245_row2_col5, #T_ef245_row2_col6, #T_ef245_row3_col0, #T_ef245_row3_col1, #T_ef245_row3_col2, #T_ef245_row3_col3, #T_ef245_row3_col4, #T_ef245_row3_col5, #T_ef245_row3_col6, #T_ef245_row4_col0, #T_ef245_row4_col1, #T_ef245_row4_col2, #T_ef245_row4_col3, #T_ef245_row4_col4, #T_ef245_row4_col5, #T_ef245_row4_col6, #T_ef245_row5_col0, #T_ef245_row5_col1, #T_ef245_row5_col2, #T_ef245_row5_col3, #T_ef245_row5_col4, #T_ef245_row5_col5, #T_ef245_row5_col6, #T_ef245_row6_col0, #T_ef245_row6_col1, #T_ef245_row6_col2, #T_ef245_row6_col3, #T_ef245_row6_col4, #T_ef245_row6_col5, #T_ef245_row6_col6, #T_ef245_row7_col0, #T_ef245_row7_col1, #T_ef245_row7_col2, #T_ef245_row7_col3, #T_ef245_row7_col4, #T_ef245_row7_col5, #T_ef245_row7_col6, #T_ef245_row8_col0, #T_ef245_row8_col1, #T_ef245_row8_col2, #T_ef245_row8_col3, #T_ef245_row8_col4, #T_ef245_row8_col5, #T_ef245_row8_col6, #T_ef245_row9_col0, #T_ef245_row9_col1, #T_ef245_row9_col2, #T_ef245_row9_col3, #T_ef245_row9_col4, #T_ef245_row9_col5, #T_ef245_row9_col6, #T_ef245_row10_col0, #T_ef245_row10_col1, #T_ef245_row10_col2, #T_ef245_row10_col3, #T_ef245_row10_col4, #T_ef245_row10_col5, #T_ef245_row10_col6, #T_ef245_row11_col0, #T_ef245_row11_col1, #T_ef245_row11_col2, #T_ef245_row11_col3, #T_ef245_row11_col4, #T_ef245_row11_col5, #T_ef245_row11_col6, #T_ef245_row12_col0, #T_ef245_row12_col1, #T_ef245_row12_col2, #T_ef245_row12_col3, #T_ef245_row12_col4, #T_ef245_row12_col5, #T_ef245_row12_col6, #T_ef245_row13_col0, #T_ef245_row13_col1, #T_ef245_row13_col2, #T_ef245_row13_col3, #T_ef245_row13_col4, #T_ef245_row13_col5, #T_ef245_row13_col6, #T_ef245_row14_col0, #T_ef245_row14_col1, #T_ef245_row14_col2, #T_ef245_row14_col3, #T_ef245_row14_col4, #T_ef245_row14_col5, #T_ef245_row14_col6, #T_ef245_row15_col0, #T_ef245_row15_col1, #T_ef245_row15_col2, #T_ef245_row15_col3, #T_ef245_row15_col4, #T_ef245_row15_col5, #T_ef245_row15_col6, #T_ef245_row16_col0, #T_ef245_row16_col1, #T_ef245_row16_col2, #T_ef245_row16_col3, #T_ef245_row16_col4, #T_ef245_row16_col5, #T_ef245_row16_col6, #T_ef245_row17_col0, #T_ef245_row17_col1, #T_ef245_row17_col2, #T_ef245_row17_col3, #T_ef245_row17_col4, #T_ef245_row17_col5, #T_ef245_row17_col6, #T_ef245_row18_col0, #T_ef245_row18_col1, #T_ef245_row18_col2, #T_ef245_row18_col3, #T_ef245_row18_col4, #T_ef245_row18_col5, #T_ef245_row18_col6 {
#   text-align: left;
# }
# #T_ef245_row0_col1, #T_ef245_row0_col3, #T_ef245_row0_col4, #T_ef245_row0_col5, #T_ef245_row0_col6, #T_ef245_row1_col2, #T_ef245_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ef245_row0_col7, #T_ef245_row1_col7, #T_ef245_row2_col7, #T_ef245_row4_col7, #T_ef245_row5_col7, #T_ef245_row6_col7, #T_ef245_row7_col7, #T_ef245_row8_col7, #T_ef245_row9_col7, #T_ef245_row10_col7, #T_ef245_row11_col7, #T_ef245_row12_col7, #T_ef245_row13_col7, #T_ef245_row14_col7, #T_ef245_row15_col7, #T_ef245_row16_col7, #T_ef245_row17_col7, #T_ef245_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ef245_row3_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ef245_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef245_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_ef245_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_ef245_row0_col1" class="data row0 col1" >352.3594</td>
#       <td id="T_ef245_row0_col2" class="data row0 col2" >319220.4908</td>
#       <td id="T_ef245_row0_col3" class="data row0 col3" >562.6808</td>
#       <td id="T_ef245_row0_col4" class="data row0 col4" >0.8215</td>
#       <td id="T_ef245_row0_col5" class="data row0 col5" >0.1025</td>
#       <td id="T_ef245_row0_col6" class="data row0 col6" >0.0627</td>
#       <td id="T_ef245_row0_col7" class="data row0 col7" >0.3400</td>
#     </tr>
#     <tr>
#       <th id="T_ef245_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_ef245_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ef245_row1_col1" class="data row1 col1" >354.0411</td>
#       <td id="T_ef245_row1_col2" class="data row1 col2" >319131.8609</td>
#       <td id="T_ef245_row1_col3" class="data row1 col3" >562.8347</td>
#       <td id="T_ef245_row1_col4" class="data row1 col4" >0.8215</td>
#       <td id="T_ef245_row1_col5" class="data row1 col5" >0.1026</td>
#       <td id="T_ef245_row1_col6" class="data row1 col6" >0.0631</td>
#       <td id="T_ef245_row1_col7" class="data row1 col7" >0.3600</td>
#     </tr>
#     <tr>
#       <th id="T_ef245_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_ef245_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_ef245_row2_col1" class="data row2 col1" >367.6010</td>
#       <td id="T_ef245_row2_col2" class="data row2 col2" >337192.4328</td>
#       <td id="T_ef245_row2_col3" class="data row2 col3" >578.5707</td>
#       <td id="T_ef245_row2_col4" class="data row2 col4" >0.8114</td>
#       <td id="T_ef245_row2_col5" class="data row2 col5" >0.1057</td>
#       <td id="T_ef245_row2_col6" class="data row2 col6" >0.0658</td>
#       <td id="T_ef245_row2_col7" class="data row2 col7" >0.2490</td>
#     </tr>
#     <tr>
#       <th id="T_ef245_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_ef245_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_ef245_row3_col1" class="data row3 col1" >367.6219</td>
#       <td id="T_ef245_row3_col2" class="data row3 col2" >337143.7062</td>
#       <td id="T_ef245_row3_col3" class="data row3 col3" >578.5225</td>
#       <td id="T_ef245_row3_col4" class="data row3 col4" >0.8114</td>
#       <td id="T_ef245_row3_col5" class="data row3 col5" >0.1057</td>
#       <td id="T_ef245_row3_col6" class="data row3 col6" >0.0659</td>
#       <td id="T_ef245_row3_col7" class="data row3 col7" >0.2480</td>
#     </tr>
#     <tr>
#       <th id="T_ef245_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_ef245_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_ef245_row4_col1" class="data row4 col1" >367.6158</td>
#       <td id="T_ef245_row4_col2" class="data row4 col2" >337143.7078</td>
#       <td id="T_ef245_row4_col3" class="data row4 col3" >578.5224</td>
#       <td id="T_ef245_row4_col4" class="data row4 col4" >0.8114</td>
#       <td id="T_ef245_row4_col5" class="data row4 col5" >0.1057</td>
#       <td id="T_ef245_row4_col6" class="data row4 col6" >0.0659</td>
#       <td id="T_ef245_row4_col7" class="data row4 col7" >0.2550</td>
#     </tr>
#     <tr>
#       <th id="T_ef245_level0_row5" class="row_heading level0 row5" >br</th>
#       <td id="T_ef245_row5_col0" class="data row5 col0" >Bayesian Ridge</td>
#       <td id="T_ef245_row5_col1" class="data row5 col1" >367.6333</td>
#       <td id="T_ef245_row5_col2" class="data row5 col2" >337144.6165</td>
#       <td id="T_ef245_row5_col3" class="data row5 col3" >578.5234</td>
#       <td id="T_ef245_row5_col4" class="data row5 col4" >0.8114</td>
#       <td id="T_ef245_row5_col5" class="data row5 col5" >0.1057</td>
#       <td id="T_ef245_row5_col6" class="data row5 col6" >0.0659</td>
#       <td id="T_ef245_row5_col7" class="data row5 col7" >0.2550</td>
#     </tr>
#     <tr>
#       <th id="T_e
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]
# GradientBoostingRegressor(random_state=1067)

# %% [markdown]
# # Hyperparameters Optimization

# %%
cv = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
def gbr(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 1000)
    learning_rate = trial.suggest_uniform('learning_rate', 0.001, 0.1)
    max_depth = trial.suggest_int('max_depth', 2, 10)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    
    model = GradientBoostingRegressor(n_estimators=n_estimators,
                                       learning_rate=learning_rate,
                                       max_depth=max_depth,
                                       min_samples_split=min_samples_split,
                                       min_samples_leaf=min_samples_leaf)
    
    model.fit(X, y)

    cv_scores = (-cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv))
    
    return np.mean(cv_scores)

# %%
def lgbm(trial):
    params = {
        'objective': 'regression',
        'metric': 'mse',
        'verbosity': -1,
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 2, 256),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.001, 1),
        'subsample': trial.suggest_float('subsample', 0.1, 1),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.1, 1),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.1, 1),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        'max_depth': trial.suggest_int('max_depth', 2, 30),
        'lambda_l1': trial.suggest_loguniform('lambda_l1', 1e-8, 10.0),
        'lambda_l2': trial.suggest_loguniform('lambda_l2', 1e-8, 10.0),
        'min_gain_to_split': trial.suggest_loguniform('min_gain_to_split', 0.1, 5),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 100),
        'random_state': 42
    }
    
    model = LGBMRegressor(**params)
    
    model.fit(X, y)
    
    cv_scores = (-cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv))
    
    return np.mean(cv_scores)

# %%
def xgb(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 1000)
    learning_rate = trial.suggest_uniform('learning_rate', 0.001, 0.1)
    max_depth = trial.suggest_int('max_depth', 2, 10)
    subsample = trial.suggest_uniform('subsample', 0.1, 1.0)
    colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.1, 1.0)
    
    model = XGBRegressor(n_estimators=n_estimators,
                             learning_rate=learning_rate,
                             max_depth=max_depth,
                             subsample=subsample,
                             colsample_bytree=colsample_bytree)
    
    model.fit(X, y)
    
    cv_scores = (-cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv))
    
    return np.mean(cv_scores)

# %%
def rfr(trial):
    n_estimators = trial.suggest_int('n_estimators', 50, 1000, step=100)
    max_depth = trial.suggest_int('max_depth', 2, 30, step=2)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    max_features = trial.suggest_uniform('max_features', 0.1, 1.0)
    
    model = RandomForestRegressor(n_estimators=n_estimators,
                                   max_depth=max_depth,
                                   min_samples_split=min_samples_split,
                                   min_samples_leaf=min_samples_leaf,
                                   max_features=max_features)

    cv_scores = (-cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv))
    
    return np.mean(cv_scores)

# %%
def lr(trial):
    fit_intercept = trial.suggest_categorical('fit_intercept', [True, False])
    
    model = LinearRegression(fit_intercept=fit_intercept)
    
    model.fit(X, y)
    
    cv_scores = (-cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv))
    
    return np.mean(cv_scores)

# %%
# study = optuna.create_study(direction='minimize')
# optuna.logging.set_verbosity(optuna.logging.WARNING)
# study.optimize(gbr, n_trials=10)
# study.best_params

# %%
# study = optuna.create_study(direction='minimize')
# optuna.logging.set_verbosity(optuna.logging.WARNING)
# study.optimize(lgbm, n_trials=10)
# study.best_params

# %%
# study = optuna.create_study(direction='minimize')
# optuna.logging.set_verbosity(optuna.logging.WARNING)
# study.optimize(xgb, n_trials=10)
# study.best_params

# %%
# study = optuna.create_study(direction='minimize')
# optuna.logging.set_verbosity(optuna.logging.WARNING)
# study.optimize(rfr, n_trials=10)
# study.best_params
# Out:
# {'n_estimators': 250,
#  'max_depth': 10,
#  'min_samples_split': 9,
#  'min_samples_leaf': 7,
#  'max_features': 0.5948849797578675}

# %%
study = optuna.create_study(direction='minimize')
optuna.logging.set_verbosity(optuna.logging.WARNING)
study.optimize(lr, n_trials=10)
study.best_params
# Out:
# {'fit_intercept': True}

# %%
gbr_params = {
    'n_estimators': 628,
    'learning_rate': 0.026814785486835847,
    'max_depth': 4,
    'min_samples_split': 3,
    'min_samples_leaf': 4
}

lgbm_params = {
    'num_leaves': 232,
    'learning_rate': 0.1137686170603685,
    'subsample': 0.4044019803234593,
    'feature_fraction': 0.8099055695071087,
    'bagging_fraction': 0.541502408613528,
    'bagging_freq': 5,
    'min_child_samples': 70,
    'max_depth': 21,
    'lambda_l1': 0.05329494892804923,
    'lambda_l2': 6.311545728826287e-08,
    'min_gain_to_split': 4.205206694599534,
    'min_data_in_leaf': 65
}

xgb_params = {
    'n_estimators': 868,
    'learning_rate': 0.008937567003123183,
    'max_depth': 6,
    'subsample': 0.4354423590142782,
    'colsample_bytree': 0.7196130540143318
}

rfr_params = {
    'n_estimators': 250,
    'max_depth': 10,
    'min_samples_split': 9,
    'min_samples_leaf': 7,
    'max_features': 0.5948849797578675
}

lr_params = {
    'fit_intercept': True
}

# %%
gbr_model = GradientBoostingRegressor(**gbr_params)
lgbm_model = LGBMRegressor(**lgbm_params)
xgb_model = XGBRegressor(**xgb_params)
rfr_model = RandomForestRegressor(**rfr_params)
lr_model = LinearRegression(**lr_params)

# %%
models = {
    'gbr': gbr_model,
    'lgbm': lgbm_model,
    'xgb': xgb_model,
    'rf': rfr_model,
    'lr': lr_model
}

# %% [markdown]
# # Model Evaluation

# %%
results_ensemble_models = {}

for name, model in models.items():
    res=[]
    res.append(-cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv))
    results_ensemble_models[name] = res
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.8099055695071087, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8099055695071087
# [LightGBM] [Warning] min_data_in_leaf is set=65, min_child_samples=70 will be ignored. Current value: min_data_in_leaf=65
# [LightGBM] [Warning] min_gain_to_split is set=4.205206694599534, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=4.205206694599534
# [LightGBM] [Warning] lambda_l1 is set=0.05329494892804923, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05329494892804923
# [LightGBM] [Warning] bagging_fraction is set=0.541502408613528, subsample=0.4044019803234593 will be ignored. Current value: bagging_fraction=0.541502408613528
# [LightGBM] [Warning] lambda_l2 is set=6.311545728826287e-08, reg_lambda=0.0 will be ignored. Current value: lambda_l2=6.311545728826287e-08
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5

# %%
for name, result in results_ensemble_models.items():
    print("----------\n" + name)
    print(np.mean(result))
    print(np.std(result))
# Out:
# ----------
# gbr
# 352.4553242074387
# 14.049145559389244
# ----------
# lgbm
# 368.4664443682223
# 14.582535523973732
# ----------
# xgb
# 350.45511018730156
# 13.919921912035036
# ----------
# rf
# 348.9578539368479
# 15.329797286875664
# ----------
# lr
# 371.8722696588751
# 14.243126176685806

# %%
final_model = VotingRegressor([('gbr', gbr_model), 
                               ('xgb', xgb_model),
                               ('rfr', rfr_model)],
                              weights=[.3, .3, .4])

results_ensemble = []
    
results_ensemble.append(-cross_val_score(final_model, X, y, scoring='neg_mean_absolute_error', cv=cv))

print(np.mean(results_ensemble))
# Out:
# 348.22249192095825

# %% [markdown]
# # Training

# %%
final_model.fit(X, y)
# Out:
# VotingRegressor(estimators=[('gbr',
#                              GradientBoostingRegressor(learning_rate=0.026814785486835847,
#                                                        max_depth=4,
#                                                        min_samples_leaf=4,
#                                                        min_samples_split=3,
#                                                        n_estimators=628)),
#                             ('xgb',
#                              XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=0.7196130540143318,
#                                           enable_categorical=False, gamma=None,
#                                           gpu_id=None, import...
#                                           num_parallel_tree=None,
#                                           predictor=None, random_state=None,
#                                           reg_alpha=None, reg_lambda=None,
#                                           scale_pos_weight=None,
#                                           subsample=0.4354423590142782,
#                                           tree_method=None,
#                                           validate_parameters=None,
#                                           verbosity=None)),
#                             ('rfr',
#                              RandomForestRegressor(max_depth=10,
#                                                    max_features=0.5948849797578675,
#                                                    min_samples_leaf=7,
#                                                    min_samples_split=9,
#                                                    n_estimators=250))],
#                 weights=[0.3, 0.3, 0.4])

# %% [markdown]
# # Prediction

# %%
y_pred = final_model.predict(test_transformed)

# %% [markdown]
# # Submission

# %%
submission = pd.DataFrame(pd.concat([pd.Series(test_transformed.index, name='id'), pd.Series(y_pred, name='yield')], axis=1))

# %%
submission.to_csv('bagging_model.csv', index=False)
